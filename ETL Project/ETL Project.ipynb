# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
csv_file = "economic_freedom.csv"
freedom_data_df = pd.read_csv(csv_file)
freedom_data_df.head()
# Out:
#   Country name  index year  overall score  property rights  \
# 0  Afghanistan        2016            NaN              NaN
# 1      Albania        2016           65.9             35.0
# 2      Algeria        2016           50.1             25.0
# 3       Angola        2016           48.9             15.0
# 4    Argentina        2016           43.8             15.0
#
#    government integrity  judicial effectiveness  tax burden  \
# 0                  12.0                     NaN        91.6
# 1                  33.0                     NaN        87.8
# 2                  36.0                     NaN        81.0
# 3                  19.0                     NaN        87.8
# 4                  34.0                     NaN        66.1
#
#    government spending  fiscal health  business freedom  labor freedom  \
# 0                 81.2            NaN              56.6           63.2
# 1                 75.0            NaN              67.6           51.5
# ...

# %%
new_freedom_data=freedom_data_df=
